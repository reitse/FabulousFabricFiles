# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

# %%
df = spark.sql("SELECT count(*) FROM Demo_Lakehouse_2CU.fact_orderlinesGen2 LIMIT 1000")
display(df)
# Out:
# StatementMeta(, f132c408-0798-4d46-b769-cdf7c577ee79, 3, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 0026581d-aaf8-4755-ba9c-493e6c88b9bf)
