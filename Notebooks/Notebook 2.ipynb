# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

# %%
df = spark.sql("SELECT count(*) FROM Demo_Lakehouse_2CU.fact_orderlinesGen2 LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 5abf3635-eb42-4354-9bc9-265d57e1402c, 4, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 2e7ee7e7-3bd2-4cd0-9858-aad3a9533e32)
