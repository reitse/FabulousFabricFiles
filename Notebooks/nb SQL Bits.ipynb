# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
print ("Hello SQL Bits!")
# Out:
# StatementMeta(, 07f2272f-00ce-4322-b808-3374734cff68, 3, Finished, Available)
# Hello SQL Bits!

# %%
import pandas as pd

# Series == Array of elements/items
series = pd.Series([1001, 1002, 1003, 1004, 1005])

print(series)
# Out:
# StatementMeta(, e18bf709-ae8a-434c-8388-036d557d126a, 3, Finished, Available)
# 0    1001
# 1    1002
# 2    1003
# 3    1004
# 4    1005
# dtype: int64

# %%
from datetime import date, datetime, timedelta

# Dataframe == Dictionary + Series
dataframe = pd.DataFrame(
  {
    'OrderID':      [1001, 1002, 1003, 1004, 1005],
    'CustomerID':   [5, 3, 2, 4, 6],
    'OrderDate':    [date(2023,3,2), date(2023,3,15),date(2023,3,30), date(2023,4,2), date(2023,4,11)],
    'ShipDate':     [date(2023,3,6), date(2023,3,16),date(2023,4,1), date(2023,4,6), date(2023,4,15)],
    'CustomerName': ['John', 'Mike','Jane', 'Tom', 'Angela'],
    'ProductID':    [101, 202, 203, 404, 606],
    'Qty':          [1, 2, 1, 4, 10],
    'Price':        [2.15, 2.59, 4.08, 1.55, 3.54]
  }
)
dataframe.info()
# Out:
# StatementMeta(, e18bf709-ae8a-434c-8388-036d557d126a, 4, Finished, Available)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       5 non-null      int64
#  1   CustomerID    5 non-null      int64
#  2   OrderDate     5 non-null      object
#  3   ShipDate      5 non-null      object
#  4   CustomerName  5 non-null      object
#  5   ProductID     5 non-null      int64
#  6   Qty           5 non-null      int64
#  7   Price         5 non-null      float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 448.0+ bytes

# %%
# Cast the Date columns to datetime data type
dataframe['OrderDate'] = dataframe['OrderDate'].astype('datetime64[ns]')
dataframe['ShipDate']  = dataframe['ShipDate'].astype('datetime64[ns]')
dataframe.info()
# Out:
# StatementMeta(, e18bf709-ae8a-434c-8388-036d557d126a, 6, Finished, Available)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       5 non-null      int64
#  1   CustomerID    5 non-null      int64
#  2   OrderDate     5 non-null      datetime64[ns]
#  3   ShipDate      5 non-null      datetime64[ns]
#  4   CustomerName  5 non-null      object
#  5   ProductID     5 non-null      int64
#  6   Qty           5 non-null      int64
#  7   Price         5 non-null      float64
# dtypes: datetime64[ns](2), float64(1), int64(4), object(1)
# memory usage: 448.0+ bytes

# %%
import math
import numpy as np


# Column == Series
seriesQty = dataframe['Qty'] 
seriesPrice = dataframe['Price'] 

# Use Vectorized Operations to create Calculated Columns
seriesLineTotal        = dataframe['Qty'] * dataframe['Price']
dataframe['LineTotal'] = dataframe['Qty'] * dataframe['Price'] 

# Error:math.ceil() only works for scalar values
dataframe['LineTotal'] = math.ceil(dataframe['Qty'] * dataframe['Price']) 
# Correct: np.ceil() support Vectorized Operations
dataframe['LineTotal'] = np.ceil(dataframe['Qty'] * dataframe['Price'])

#dataframe['Year'] = dataframe['OrderDate'].year # Wrong series doesn't have a year property!
dataframe['Year'] = dataframe['OrderDate'].dt.year
dataframe['LeadTime'] = (dataframe['ShipDate'] - dataframe['OrderDate']).dt.days

dataframe['Lower'] = dataframe['CustomerName'].str.lower()
dataframe['FirstUpper'] = dataframe['CustomerName'].str[0].str.upper() 

display(dataframe)
# Out:
# StatementMeta(, e18bf709-ae8a-434c-8388-036d557d126a, 7, Finished, Available)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 14
#      11 dataframe['LineTotal'] = dataframe['Qty'] * dataframe['Price']
#      13 # Error:math.ceil() only works for scalar values
# ---> 14 dataframe['LineTotal'] = math.ceil(dataframe['Qty'] * dataframe['Price'])
#      15 # Correct: np.ceil() support Vectorized Operations
#      16 dataframe['LineTotal'] = np.ceil(dataframe['Qty'] * dataframe['Price'])
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/pandas/core/series.py:230, in _coerce_method.<locals>.wrapper(self)
#     222     warnings.warn(
#     223         f"Calling {converter.__name__} on a single element Series is "
#     224         "deprecated and will raise a TypeError in the future. "
#    (...)
#     227         stacklevel=find_stack_level(),
#     228     )
#     229     return converter(self.iloc[0])
# --> 230 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'float'>

# %%
# Get DataFrame Schema
dataframe.info()

# Get # of rows and columns
print( dataframe.shape )                   # (5,6)   

# Get Columns
print(dataframe.columns)
# Out:
# StatementMeta(, e18bf709-ae8a-434c-8388-036d557d126a, 8, Finished, Available)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       5 non-null      int64
#  1   CustomerID    5 non-null      int64
#  2   OrderDate     5 non-null      datetime64[ns]
#  3   ShipDate      5 non-null      datetime64[ns]
#  4   CustomerName  5 non-null      object
#  5   ProductID     5 non-null      int64
#  6   Qty           5 non-null      int64
#  7   Price         5 non-null      float64
#  8   LineTotal     5 non-null      float64
# dtypes: datetime64[ns](2), float64(2), int64(4), object(1)
# memory usage: 488.0+ bytes
# (5, 9)
# Index(['OrderID', 'CustomerID', 'OrderDate', 'ShipDate', 'CustomerName',
#        'ProductID', 'Qty', 'Price', 'LineTotal'],
#       dtype='object')

# %%
# Iterate throug all the rows
for ind, item in dataframe.iterrows():
  print(f'Index: {ind} Brand: {item["brand"]}')
# Out:
# StatementMeta(, e18bf709-ae8a-434c-8388-036d557d126a, 9, Finished, Available)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'brand'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 3
#       1 # Iterate throug all the rows
#       2 for ind, item in dataframe.iterrows():
# ----> 3   print(f'Index: {ind} Brand: {item["brand"]}')
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/pandas/core/series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/pandas/core/series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'brand'

# %%
#print( dataframe[0] )                    # wrong 
print( dataframe.brand )                  # All data in brand column
print( dataframe['brand'] )               # All data in brand column
print( dataframe['brand'][0:3] )          # First 3 items in brand column
print( dataframe[['passings','brand'  ]]) # All rows with passing and brand column
